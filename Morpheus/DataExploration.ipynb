# %% [markdown]
# # Exploring SigMorphon 2019 Task 2 Datasets

# %%
from itertools import chain
import os
import pandas as pd

# %% [markdown]
# ## Required functions and classes

# %%
class Sentence(object):
    """Sentence class with surface words, lemmas and morphological tags
    
    """
    
    def __init__(self, conll_sentence):
        """Create a Sentence object from a conll sentence
        
        Arguments:
            conll_sentence: (list) list of conll lines correspond to one sentence
        """
        self.surface_words = []
        self.lemmas = []
        self.morph_tags = []
        
        for conll_token in conll_sentence:
            if not conll_token or conll_token.startswith('#'):
                continue
            _splits = conll_token.split('\t')
            self.surface_words.append(_splits[1])
            self.lemmas.append(_splits[2])
            self.morph_tags.append(_splits[5].split(';'))
            
    def get_tags_as_str(self):
        return [';'.join(morph_tags) for morph_tags in self.morph_tags]
            
    
    def __repr__(self):
        return "\n".join(
            ['Surface: {}, Lemma: {}, MorphTags: {}'.format(surface, lemma, ';'.join(morph_tags))
             for surface, lemma, morph_tags in zip(self.surface_words, self.lemmas, self.morph_tags)]
        )

# %%
def read_dataset(conll_file):
    """Read Conll dataset
    
    Argumets:
        conll_file: (str) conll file path
    Returns:
        list: list of `Sentence` objects
    """
    sentences = []
    with open(conll_file, 'r', encoding='UTF-8') as f:
        conll_sentence = []
        for line in f:
            if len(line.strip())==0:
                if len(conll_sentence) > 0:
                    sentence = Sentence(conll_sentence)
                    sentences.append(sentence)
                conll_sentence = []
            else:
                conll_sentence.append(line)
    return sentences

# %%
def get_stats(sentences):
    """Calculate statistics of surface words, lemmas and morphological tags in given sentences
    
    Arguments:
        sentences: (list) list of `Sentence` objects
    Returns:
        dict: stats dict
    """
    
    def flatten(_list):
        return list(chain(*_list))
    
    number_of_sentences = len(sentences)
    number_of_tokens = len(flatten([sentence.surface_words for sentence in sentences]))
    number_of_unique_words = len(set(flatten([sentence.surface_words for sentence in sentences])))
    number_of_unique_lemmas = len(set(flatten([sentence.lemmas for sentence in sentences])))
    number_of_unique_tags = len(set(flatten([sentence.get_tags_as_str() for sentence in sentences])))
    number_of_unique_features = len(set(flatten(flatten([sentence.morph_tags for sentence in sentences]))))
    
    return {
        'Number of sentence': number_of_sentences,
        'Number of tokens': number_of_tokens,
        'Number of unique words': number_of_unique_words,
        'Number of unique lemmas': number_of_unique_lemmas,
        'Number of unique morphological tags': number_of_unique_tags,
        'Number of unique morphological features': number_of_unique_features
    }

# %% [markdown]
# ## Create datasets and stats for each language

# %%
language_paths = ['data/2019/task2/' + filename for filename in os.listdir('data/2019/task2/')]
language_names = [filename.replace('UD_', '') for filename in os.listdir('data/2019/task2/')]

# %%
print(os.listdir(language_paths[0]))
# Out:
# ['en_gum-um-covered-test.conllu', 'en_gum-um-decoder_lemma.model', 'en_gum-um-decoder_morph.model', 'en_gum-um-dev.conllu', 'en_gum-um-encoder.model', 'en_gum-um-predictions.conllu', 'en_gum-um-train.conllu', 'en_gum-um.dataset']

# %%
datasets_train = {}
datasets_val = {}
dataset_stats = {}
for language_path, language_name in zip(language_paths, language_names):
    language_conll_files = list(filter(lambda x: "train.conll" in x or "test.conll" in x, os.listdir(language_path)))
    assert len(language_conll_files) == 2, 'More than 2 files'
    for language_conll_file in language_conll_files:
        if 'train' in language_conll_file:
            datasets_train[language_name] = read_dataset(language_path + '/' + language_conll_file)
            dataset_stats[language_name] = get_stats(datasets_train[language_name])
        else:
            datasets_val[language_name] = read_dataset(language_path + '/' + language_conll_file)

# %%
datasets_train["English-GUM"]
# Out:
# [Surface: 1, Lemma: 1, MorphTags: NUM
#  Surface: Quaffle, Lemma: Quaffle, MorphTags: SG;N
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: volleyball, Lemma: volleyball, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Frisbee, Lemma: Frisbee, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: soccer, Lemma: soccer, MorphTags: SG;N
#  Surface: ball, Lemma: ball, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: etc, Lemma: etc, MorphTags: _
#  Surface: ., Lemma: ., MorphTags: _
#  Surface: ), Lemma: ), MorphTags: _,
#  Surface: So, Lemma: so, MorphTags: ADV
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: way, Lemma: way, MorphTags: SG;N
#  Surface: people, Lemma: people, MorphTags: PL;N
#  Surface: often, Lemma: often, MorphTags: ADV
#  Surface: do, Lemma: do, MorphTags: PRS;V;FIN;IND
#  Surface: n't, Lemma: n't, MorphTags: NEG;PART
#  Surface: know, Lemma: know, MorphTags: NFIN;V
#  Surface: how, Lemma: how, MorphTags: CONJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: combine, Lemma: combine, MorphTags: NFIN;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: two, Lemma: two, MorphTags: NUM
#  Surface: fields, Lemma: field, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Everything, Lemma: Everything, MorphTags: SG;N
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: white, Lemma: white, MorphTags: ADJ
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: hospital-like, Lemma: hospital-like, MorphTags: ADJ
#  Surface: but, Lemma: but, MorphTags: CONJ
#  Surface: there, Lemma: there, MorphTags: PRO
#  Surface: ’s, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: no, Lemma: no, MorphTags: DET;NEG
#  Surface: examining, Lemma: examining, MorphTags: SG;N
#  Surface: couch, Lemma: couch, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: So, Lemma: so, MorphTags: ADV
#  Surface: ultimately, Lemma: ultimately, MorphTags: ADV
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: decided, Lemma: decide, MorphTags: PST;FIN;IND;V
#  Surface: that, Lemma: that, MorphTags: CONJ
#  Surface: eHow, Lemma: eHow, MorphTags: SG;PROPN
#  Surface: 's, Lemma: 's, MorphTags: PART
#  Surface: model, Lemma: model, MorphTags: SG;N
#  Surface: would, Lemma: would, MorphTags: V;FIN
#  Surface: not, Lemma: not, MorphTags: NEG;PART
#  Surface: build, Lemma: build, MorphTags: NFIN;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: resource, Lemma: resource, MorphTags: SG;N
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: envisioned, Lemma: envision, MorphTags: PST;FIN;IND;V
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: It, Lemma: it, MorphTags: NOM;PRO;SG;3;NEUT
#  Surface: was, Lemma: be, MorphTags: V;IND;FIN;SG;3;PST
#  Surface: n’t, Lemma: n't, MorphTags: NEG;PART
#  Surface: as, Lemma: as, MorphTags: ADV
#  Surface: loud, Lemma: loud, MorphTags: ADJ
#  Surface: as, Lemma: as, MorphTags: ADP
#  Surface: my, Lemma: my, MorphTags: 1;PRO;SG
#  Surface: heels, Lemma: heel, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Your, Lemma: your, MorphTags: 2;PRO
#  Surface: reserve, Lemma: reserve, MorphTags: SG;N
#  Surface: chute, Lemma: chute, MorphTags: SG;N
#  Surface: should, Lemma: should, MorphTags: V;FIN
#  Surface: have, Lemma: have, MorphTags: NFIN;V
#  Surface: been, Lemma: be, MorphTags: PST;V.PTCP;V
#  Surface: packed, Lemma: pack, MorphTags: PST;V.PTCP;V
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: certified, Lemma: certified, MorphTags: ADJ
#  Surface: rigger, Lemma: rigger, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: moderately, Lemma: moderately, MorphTags: ADV
#  Surface: less, Lemma: less, MorphTags: CMPR;ADV
#  Surface: likely, Lemma: likely, MorphTags: ADJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: fail, Lemma: fail, MorphTags: NFIN;V
#  Surface: ;, Lemma: ;, MorphTags: _,
#  Surface: This, Lemma: this, MorphTags: PRO;SG
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: make, Lemma: make, MorphTags: NFIN;V
#  Surface: grammar, Lemma: grammar, MorphTags: SG;N
#  Surface: much, Lemma: much, MorphTags: ADV
#  Surface: easier, Lemma: easy, MorphTags: CMPR;ADJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: make, Lemma: make, MorphTags: NFIN;V
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: current, Lemma: current, MorphTags: ADJ
#  Surface: study, Lemma: study, MorphTags: SG;N
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: contribute, Lemma: contribute, MorphTags: NFIN;V
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: development, Lemma: development, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: further, Lemma: further, MorphTags: CMPR;ADJ
#  Surface: qualitative, Lemma: qualitative, MorphTags: ADJ
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: quantitative, Lemma: quantitative, MorphTags: ADJ
#  Surface: research, Lemma: research, MorphTags: SG;N
#  Surface: that, Lemma: that, MorphTags: PRO
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: more, Lemma: more, MorphTags: ADV
#  Surface: clearly, Lemma: clearly, MorphTags: ADV
#  Surface: define, Lemma: define, MorphTags: NFIN;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: information, Lemma: information, MorphTags: SG;N
#  Surface: behaviors, Lemma: behavior, MorphTags: PL;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: transmedia, Lemma: transmedia, MorphTags: SG;N
#  Surface: fan, Lemma: fan, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Dance, Lemma: dance, MorphTags: NFIN;V
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: elevator, Lemma: elevator, MorphTags: SG;N
#  Surface: music, Lemma: music, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Otto, Lemma: Otto, MorphTags: PROPN;SG
#  Surface: Jespersen, Lemma: Jespersen, MorphTags: PROPN;SG,
#  Surface: ', Lemma: ', MorphTags: _
#  Surface: aviatio, Lemma: aviatio, MorphTags: _
#  Surface: ', Lemma: ', MorphTags: _
#  Surface: comes, Lemma: come, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: English, Lemma: English, MorphTags: SG;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: 1/2, Lemma: @card@, MorphTags: NUM
#  Surface: cup, Lemma: cup, MorphTags: N;SG
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: 120, Lemma: @card@, MorphTags: NUM
#  Surface: ml, Lemma: ml, MorphTags: N;SG
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: vegetable, Lemma: vegetable, MorphTags: N;SG
#  Surface: oil, Lemma: oil, MorphTags: N;SG,
#  Surface: We, Lemma: we, MorphTags: NOM;1;PRO;PL
#  Surface: hypothesized, Lemma: hypothesize, MorphTags: PST;FIN;IND;V
#  Surface: that, Lemma: that, MorphTags: CONJ
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: children, Lemma: child, MorphTags: PL;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: who, Lemma: who, MorphTags: PRO
#  Surface: were, Lemma: be, MorphTags: PST;FIN;IND;V
#  Surface: over, Lemma: over, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: age, Lemma: age, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: six, Lemma: six, MorphTags: NUM
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: time, Lemma: time, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: collection, Lemma: collection, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: would, Lemma: would, MorphTags: V;FIN
#  Surface: have, Lemma: have, MorphTags: NFIN;V
#  Surface: adult-like, Lemma: adult-like, MorphTags: ADJ
#  Surface: SI, Lemma: SI, MorphTags: SG;N
#  Surface: interpretations, Lemma: interpretation, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Do, Lemma: do, MorphTags: NFIN;V
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: remember, Lemma: remember, MorphTags: NFIN;V
#  Surface: ?, Lemma: ?, MorphTags: _,
#  Surface: In, Lemma: in, MorphTags: ADP
#  Surface: 1891, Lemma: @card@, MorphTags: NUM
#  Surface: she, Lemma: she, MorphTags: 3;SG;NOM;FEM;PRO
#  Surface: met, Lemma: meet, MorphTags: PST;FIN;IND;V
#  Surface: her, Lemma: her, MorphTags: 3;SG;FEM;PRO
#  Surface: future, Lemma: future, MorphTags: ADJ
#  Surface: advisor, Lemma: advisor, MorphTags: SG;N
#  Surface: who, Lemma: who, MorphTags: PRO
#  Surface: would, Lemma: would, MorphTags: V;FIN
#  Surface: help, Lemma: help, MorphTags: NFIN;V
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: she, Lemma: she, MorphTags: 3;SG;NOM;FEM;PRO
#  Surface: assumed, Lemma: assume, MorphTags: PST;FIN;IND;V
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: poet-turned-fiction-writer, Lemma: poet-turned-fiction-writer, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: connect, Lemma: connect, MorphTags: NFIN;V
#  Surface: her, Lemma: her, MorphTags: 3;SG;ACC;FEM;PRO
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: editors, Lemma: editor, MorphTags: PL;N
#  Surface: :, Lemma: :, MorphTags: _
#  Surface: Tosui, Lemma: Tosui, MorphTags: SG;PROPN
#  Surface: Nakarai, Lemma: Nakarai, MorphTags: SG;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: ", Lemma: ", MorphTags: _
#  Surface: Barn, Lemma: barn, MorphTags: N;SG
#  Surface: cats, Lemma: cat, MorphTags: N;PL
#  Surface: ", Lemma: ", MorphTags: _
#  Surface: may, Lemma: may, MorphTags: V;FIN
#  Surface: not, Lemma: not, MorphTags: NEG;PART
#  Surface: be, Lemma: be, MorphTags: V;NFIN
#  Surface: socialized, Lemma: socialize, MorphTags: V;V.PTCP;PST
#  Surface: well, Lemma: well, MorphTags: ADV
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: humans, Lemma: human, MorphTags: N;PL
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: although, Lemma: although, MorphTags: CONJ
#  Surface: used, Lemma: use, MorphTags: V;V.PTCP;PST
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: hunting, Lemma: hunting, MorphTags: V;V.MSDR
#  Surface: mice, Lemma: mouse, MorphTags: N;PL
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: food, Lemma: food, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: They, Lemma: they, MorphTags: NOM;3;PRO;PL
#  Surface: could, Lemma: could, MorphTags: V;FIN
#  Surface: also, Lemma: also, MorphTags: ADV
#  Surface: use, Lemma: use, MorphTags: NFIN;V
#  Surface: regular-length, Lemma: regular-length, MorphTags: SG;N
#  Surface: hockey, Lemma: hockey, MorphTags: SG;N
#  Surface: sticks, Lemma: stick, MorphTags: PL;N
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: hit, Lemma: hit, MorphTags: NFIN;V
#  Surface: bludgers, Lemma: bludgers, MorphTags: PL;N
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: perhaps, Lemma: perhaps, MorphTags: ADV
#  Surface: wiffle, Lemma: wiffle, MorphTags: SG;N
#  Surface: balls, Lemma: ball, MorphTags: PL;N
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: on, Lemma: on, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: ground, Lemma: ground, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Method, Lemma: method, MorphTags: N;SG
#  Surface: 1, Lemma: 1, MorphTags: NUM
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: 2, Lemma: 2, MorphTags: NUM
#  Surface: :, Lemma: :, MorphTags: _
#  Surface: From, Lemma: from, MorphTags: ADP
#  Surface: Seeds, Lemma: Seeds, MorphTags: N;PL,
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: 'm, Lemma: be, MorphTags: PRS;V;FIN;IND
#  Surface: like, Lemma: like, MorphTags: ADJ
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: ‘, Lemma: ', MorphTags: _
#  Surface: Are, Lemma: be, MorphTags: PRS;V;FIN;IND
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: insane, Lemma: insane, MorphTags: ADJ
#  Surface: ?, Lemma: ?, MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: Independent, Lemma: Independent, MorphTags: SG;PROPN
#  Surface: reported, Lemma: report, MorphTags: PST;FIN;IND;V
#  Surface: self-medicating, Lemma: self-medicating, MorphTags: V.MSDR;V
#  Surface: ants, Lemma: ant, MorphTags: PL;N
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: first, Lemma: first, MorphTags: ADJ
#  Surface: among, Lemma: among, MorphTags: ADP
#  Surface: insects, Lemma: insect, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: It, Lemma: it, MorphTags: NEUT;SG;NOM;3;PRO
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: hub, Lemma: hub, MorphTags: SG;N
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: American, Lemma: American, MorphTags: SG;PROPN
#  Surface: Airlines, Lemma: Airlines, MorphTags: PL;PROPN
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: Southwest, Lemma: Southwest, MorphTags: SG;PROPN
#  Surface: Airlines, Lemma: Airlines, MorphTags: PL;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: history, Lemma: history, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: values, Lemma: value, MorphTags: PL;N
#  Surface: is, Lemma: be, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: okay, Lemma: okay, MorphTags: ADJ
#  Surface: because, Lemma: because, MorphTags: CONJ
#  Surface: wisdom, Lemma: wisdom, MorphTags: N;SG
#  Surface: is, Lemma: be, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: ageless, Lemma: ageless, MorphTags: ADJ
#  Surface: ;, Lemma: ;, MorphTags: _
#  Surface: it, Lemma: it, MorphTags: NOM;PRO;SG;3;NEUT
#  Surface: does, Lemma: do, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: n’t, Lemma: n't, MorphTags: PART
#  Surface: grow, Lemma: grow, MorphTags: NFIN;V
#  Surface: old, Lemma: old, MorphTags: ADJ
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: like, Lemma: like, MorphTags: ADP
#  Surface: material, Lemma: material, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Drink, Lemma: drink, MorphTags: NFIN;V
#  Surface: responsibly, Lemma: responsibly, MorphTags: ADV
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: 1, Lemma: 1, MorphTags: NUM
#  Surface: tablespoon, Lemma: tablespoon, MorphTags: N;SG
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: 15, Lemma: @card@, MorphTags: NUM
#  Surface: ml, Lemma: ml, MorphTags: N;PL
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: apple, Lemma: apple, MorphTags: N;SG
#  Surface: cider, Lemma: cider, MorphTags: N;SG
#  Surface: vinegar, Lemma: vinegar, MorphTags: N;SG,
#  Surface: And, Lemma: and, MorphTags: CONJ
#  Surface: having, Lemma: have, MorphTags: V.MSDR;V
#  Surface: one, Lemma: one, MorphTags: NUM
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: those, Lemma: those, MorphTags: PRO;PL
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: usually, Lemma: usually, MorphTags: ADV
#  Surface: indicative, Lemma: indicative, MorphTags: ADJ
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: arrogance, Lemma: arrogance, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Jespersen, Lemma: Jespersen, MorphTags: PROPN;SG
#  Surface: was, Lemma: be, MorphTags: SG;IND;V;PST;3;FIN
#  Surface: a, Lemma: a, MorphTags: INDF;DET
#  Surface: proponent, Lemma: proponent, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: phonosemanticism, Lemma: phonosemanticism, MorphTags: N;SG
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: wrote, Lemma: write, MorphTags: V;PST;FIN;IND
#  Surface: :, Lemma: :, MorphTags: _,
#  Surface: but, Lemma: but, MorphTags: CONJ
#  Surface: more, Lemma: more, MorphTags: ADV
#  Surface: than, Lemma: than, MorphTags: ADP
#  Surface: anything, Lemma: anything, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: there, Lemma: there, MorphTags: PRO
#  Surface: 's, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: lot, Lemma: lot, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: good, Lemma: good, MorphTags: ADJ
#  Surface: feeling, Lemma: feeling, MorphTags: SG;N
#  Surface: around, Lemma: around, MorphTags: ADP
#  Surface: here, Lemma: here, MorphTags: ADV
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Please, Lemma: Please, MorphTags: INTJ
#  Surface: note, Lemma: note, MorphTags: NFIN;V
#  Surface: that, Lemma: that, MorphTags: CONJ
#  Surface: if, Lemma: if, MorphTags: CONJ
#  Surface: departing, Lemma: depart, MorphTags: V.MSDR;V
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: Europe, Lemma: Europe, MorphTags: SG;PROPN
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: this, Lemma: this, MorphTags: PRO;SG
#  Surface: may, Lemma: may, MorphTags: V;FIN
#  Surface: apply, Lemma: apply, MorphTags: NFIN;V
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: other, Lemma: other, MorphTags: ADJ
#  Surface: countries, Lemma: country, MorphTags: PL;N
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: require, Lemma: require, MorphTags: NFIN;V
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: have, Lemma: have, MorphTags: NFIN;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: visa, Lemma: visa, MorphTags: SG;N
#  Surface: before, Lemma: before, MorphTags: CONJ
#  Surface: boarding, Lemma: board, MorphTags: V.MSDR;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: plane, Lemma: plane, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: ..., Lemma: ..., MorphTags: _
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: how, Lemma: how, MorphTags: CONJ
#  Surface: do, Lemma: do, MorphTags: FIN;V;IND;PRS
#  Surface: I, Lemma: I, MorphTags: NOM;1;PRO;SG
#  Surface: best, Lemma: good, MorphTags: ADJ;RL
#  Surface: explain, Lemma: explain, MorphTags: NFIN;V
#  Surface: this, Lemma: this, MorphTags: PRO;SG
#  Surface: ?, Lemma: ?, MorphTags: _
#  Surface: ), Lemma: ), MorphTags: _,
#  Surface: Rick, Lemma: Rick, MorphTags: SG;PROPN
#  Surface: Santorum, Lemma: Santorum, MorphTags: SG;PROPN
#  Surface: himself, Lemma: himself, MorphTags: SG;MASC;3;PRO
#  Surface: has, Lemma: have, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: acknowledged, Lemma: acknowledge, MorphTags: PST;V.PTCP;V
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: discussed, Lemma: discuss, MorphTags: PST;V.PTCP;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: existence, Lemma: existence, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: prevalence, Lemma: prevalence, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: santorum, Lemma: santorum, MorphTags: SG;N
#  Surface: neologism, Lemma: neologism, MorphTags: SG;N
#  Surface: phenomenon, Lemma: phenomenon, MorphTags: SG;N
#  Surface: ;, Lemma: ;, MorphTags: _
#  Surface: he, Lemma: he, MorphTags: SG;NOM;MASC;3;PRO
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: quoted, Lemma: quote, MorphTags: PST;V.PTCP;V
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: Canadian, Lemma: Canadian, MorphTags: SG;PROPN
#  Surface: Press, Lemma: Press, MorphTags: SG;PROPN
#  Surface: on, Lemma: on, MorphTags: ADP
#  Surface: his, Lemma: his, MorphTags: SG;MASC;3;PRO
#  Surface: assessment, Lemma: assessment, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Google, Lemma: Google, MorphTags: SG;PROPN
#  Surface: 's, Lemma: 's, MorphTags: PART
#  Surface: response, Lemma: response, MorphTags: SG;N
#  Surface: ;, Lemma: ;, MorphTags: _,
#  Surface: In, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: 1960s, Lemma: 1960s, MorphTags: PL;N
#  Surface: Hadid, Lemma: Hadid, MorphTags: SG;PROPN
#  Surface: attended, Lemma: attend, MorphTags: PST;FIN;IND;V
#  Surface: boarding, Lemma: board, MorphTags: V.MSDR;V
#  Surface: schools, Lemma: school, MorphTags: PL;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: England, Lemma: England, MorphTags: SG;PROPN
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: Switzerland, Lemma: Switzerland, MorphTags: SG;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: This, Lemma: this, MorphTags: PRO;SG
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: called, Lemma: call, MorphTags: PST;V.PTCP;V
#  Surface: ", Lemma: ", MorphTags: _
#  Surface: bolting, Lemma: bolt, MorphTags: V.MSDR;V
#  Surface: ", Lemma: ", MorphTags: _
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: more, Lemma: more, MorphTags: ADV
#  Surface: likely, Lemma: likely, MorphTags: ADJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: happen, Lemma: happen, MorphTags: NFIN;V
#  Surface: when, Lemma: when, MorphTags: CONJ
#  Surface: there, Lemma: there, MorphTags: PRO
#  Surface: 's, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: extra, Lemma: extra, MorphTags: ADJ
#  Surface: sunshine, Lemma: sunshine, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: On, Lemma: on, MorphTags: ADP
#  Surface: NATO, Lemma: NATO, MorphTags: SG;PROPN,
#  Surface: I, Lemma: I, MorphTags: NOM;1;PRO;SG
#  Surface: do, Lemma: do, MorphTags: FIN;V;IND;PRS
#  Surface: n't, Lemma: n't, MorphTags: NEG;PART
#  Surface: have, Lemma: have, MorphTags: NFIN;V
#  Surface: enough, Lemma: enough, MorphTags: ADJ
#  Surface: information, Lemma: information, MorphTags: N;SG
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: answer, Lemma: answer, MorphTags: NFIN;V
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: question, Lemma: question, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: one, Lemma: one, MorphTags: NUM
#  Surface: way, Lemma: way, MorphTags: N;SG
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: other, Lemma: other, MorphTags: ADJ
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: In, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: past, Lemma: past, MorphTags: ADJ
#  Surface: Muggle, Lemma: Muggle, MorphTags: SG;N
#  Surface: Quidditch, Lemma: Quidditch, MorphTags: SG;N
#  Surface: has, Lemma: have, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: mainly, Lemma: mainly, MorphTags: ADV
#  Surface: been, Lemma: be, MorphTags: PST;V.PTCP;V
#  Surface: played, Lemma: play, MorphTags: PST;V.PTCP;V
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: colleges, Lemma: college, MorphTags: PL;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: US, Lemma: US, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: but, Lemma: but, MorphTags: CONJ
#  Surface: over, Lemma: over, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: last, Lemma: last, MorphTags: ADJ
#  Surface: few, Lemma: few, MorphTags: ADJ
#  Surface: years, Lemma: year, MorphTags: PL;N
#  Surface: there, Lemma: there, MorphTags: PRO
#  Surface: has, Lemma: have, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: been, Lemma: be, MorphTags: PST;V.PTCP;V
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: dramatic, Lemma: dramatic, MorphTags: ADJ
#  Surface: rise, Lemma: rise, MorphTags: SG;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: number, Lemma: number, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: community, Lemma: community, MorphTags: SG;N
#  Surface: teams, Lemma: team, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: sample, Lemma: sample, MorphTags: SG;N
#  Surface: consisted, Lemma: consist, MorphTags: PST;FIN;IND;V
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: 71, Lemma: @card@, MorphTags: NUM
#  Surface: students, Lemma: student, MorphTags: PL;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: Application, Lemma: Application, MorphTags: SG;PROPN
#  Surface: School, Lemma: School, MorphTags: SG;PROPN
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Basic, Lemma: Basic, MorphTags: SG;PROPN
#  Surface: Education, Lemma: Education, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Federal, Lemma: Federal, MorphTags: SG;PROPN
#  Surface: University, Lemma: University, MorphTags: SG;PROPN
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Santa, Lemma: Santa, MorphTags: SG;PROPN
#  Surface: Catarina, Lemma: Catarina, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: aged, Lemma: age, MorphTags: PST;V.PTCP;V
#  Surface: 7, Lemma: 7, MorphTags: NUM
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: 9, Lemma: 9, MorphTags: NUM
#  Surface: years, Lemma: year, MorphTags: PL;N
#  Surface: old, Lemma: old, MorphTags: ADJ
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: M, Lemma: M, MorphTags: SG;N
#  Surface: =, Lemma: =, MorphTags: _
#  Surface: 7.64, Lemma: @card@, MorphTags: NUM
#  Surface: ±, Lemma: ±, MorphTags: SG;N
#  Surface: 1.12, Lemma: @card@, MorphTags: NUM
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: which, Lemma: which, MorphTags: PRO
#  Surface: were, Lemma: be, MorphTags: PST;V;FIN;IND
#  Surface: divided, Lemma: divide, MorphTags: PST;V.PTCP;V
#  Surface: into, Lemma: into, MorphTags: ADP
#  Surface: two, Lemma: two, MorphTags: NUM
#  Surface: groups, Lemma: group, MorphTags: PL;N
#  Surface: :, Lemma: :, MorphTags: _
#  Surface: participant, Lemma: participant, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: control, Lemma: control, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: There, Lemma: there, MorphTags: PRO
#  Surface: are, Lemma: be, MorphTags: PRS;V;FIN;IND
#  Surface: some, Lemma: some, MorphTags: DET
#  Surface: good, Lemma: good, MorphTags: ADJ
#  Surface: beaches, Lemma: beach, MorphTags: N;PL
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: plenty, Lemma: plenty, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: secluded, Lemma: secluded, MorphTags: ADJ
#  Surface: cove, Lemma: cove, MorphTags: N;SG
#  Surface: beaches, Lemma: beach, MorphTags: N;PL
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: protected, Lemma: protect, MorphTags: V;V.PTCP;PST
#  Surface: bays, Lemma: bay, MorphTags: N;PL
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: good, Lemma: good, MorphTags: ADJ
#  Surface: snorkelling, Lemma: snorkelling, MorphTags: V;V.MSDR
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DEF;DET
#  Surface: latest, Lemma: late, MorphTags: RL;ADJ
#  Surface: Newsmax, Lemma: Newsmax, MorphTags: PROPN;SG
#  Surface: /, Lemma: /, MorphTags: _
#  Surface: Zogby, Lemma: Zogby, MorphTags: PROPN;SG
#  Surface: poll, Lemma: poll, MorphTags: N;SG
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: late, Lemma: late, MorphTags: ADJ
#  Surface: September, Lemma: September, MorphTags: PROPN;SG
#  Surface: placed, Lemma: place, MorphTags: V;PST;FIN;IND
#  Surface: him, Lemma: him, MorphTags: PRO;SG;MASC;3;ACC
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: 13, Lemma: @card@, MorphTags: NUM
#  Surface: percent, Lemma: percent, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: 14, Lemma: @card@, MorphTags: NUM
#  Surface: points, Lemma: point, MorphTags: N;PL
#  Surface: behind, Lemma: behind, MorphTags: ADP
#  Surface: Republican, Lemma: Republican, MorphTags: PROPN;SG
#  Surface: Party, Lemma: Party, MorphTags: PROPN;SG
#  Surface: nominee, Lemma: nominee, MorphTags: N;SG
#  Surface: Ken, Lemma: Ken, MorphTags: PROPN;SG
#  Surface: Cuccinelli, Lemma: Cuccinelli, MorphTags: PROPN;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Virginia, Lemma: Virginia, MorphTags: PROPN;SG
#  Surface: 's, Lemma: 's, MorphTags: PART
#  Surface: Attorney, Lemma: Attorney, MorphTags: PROPN;SG
#  Surface: General, Lemma: General, MorphTags: PROPN;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: 19, Lemma: @card@, MorphTags: NUM
#  Surface: points, Lemma: point, MorphTags: N;PL
#  Surface: behind, Lemma: behind, MorphTags: ADP
#  Surface: Democratic, Lemma: Democratic, MorphTags: PROPN;SG
#  Surface: Party, Lemma: Party, MorphTags: PROPN;SG
#  Surface: nominee, Lemma: nominee, MorphTags: N;SG
#  Surface: Terry, Lemma: Terry, MorphTags: PROPN;SG
#  Surface: McAuliffe, Lemma: McAuliffe, MorphTags: PROPN;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DEF;DET
#  Surface: former, Lemma: former, MorphTags: ADJ
#  Surface: Democratic, Lemma: Democratic, MorphTags: PROPN;SG
#  Surface: National, Lemma: National, MorphTags: PROPN;SG
#  Surface: Committee, Lemma: Committee, MorphTags: PROPN;SG
#  Surface: chairman, Lemma: chairman, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: with, Lemma: with, MorphTags: CONJ
#  Surface: 24, Lemma: @card@, MorphTags: NUM
#  Surface: percent, Lemma: percent, MorphTags: N;SG
#  Surface: undecided, Lemma: undecided, MorphTags: ADJ
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Store, Lemma: Store, MorphTags: SG;N
#  Surface: hours, Lemma: hour, MorphTags: SG;N
#  Surface: :, Lemma: :, MorphTags: _
#  Surface: Mon-Fri, Lemma: Mon-Fri, MorphTags: SG;PROPN
#  Surface: 08:30, Lemma: @card@, MorphTags: NUM
#  Surface: am, Lemma: am, MorphTags: SG;PROPN
#  Surface: -, Lemma: -, MorphTags: ADP
#  Surface: 7, Lemma: 7, MorphTags: NUM
#  Surface: pm, Lemma: pm, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Sat, Lemma: sit, MorphTags: SG;PROPN
#  Surface: 08:30, Lemma: @card@, MorphTags: NUM
#  Surface: am, Lemma: am, MorphTags: SG;PROPN
#  Surface: -, Lemma: -, MorphTags: ADP
#  Surface: 06:30, Lemma: @card@, MorphTags: NUM
#  Surface: pm, Lemma: pm, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Sun, Lemma: Sun, MorphTags: SG;PROPN
#  Surface: 9, Lemma: 9, MorphTags: NUM
#  Surface: am, Lemma: am, MorphTags: SG;PROPN
#  Surface: -, Lemma: -, MorphTags: ADP
#  Surface: 03:00, Lemma: @card@, MorphTags: NUM
#  Surface: pm, Lemma: pm, MorphTags: SG;PROPN,
#  Surface: Women, Lemma: woman, MorphTags: PL;N
#  Surface: defy, Lemma: defy, MorphTags: FIN;IND;PRS;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: laws, Lemma: law, MorphTags: PL;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: purse-space, Lemma: purse-space, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: so, Lemma: so, MorphTags: ADV
#  Surface: when, Lemma: when, MorphTags: CONJ
#  Surface: it, Lemma: it, MorphTags: NOM;PRO;SG;3;NEUT
#  Surface: comes, Lemma: come, MorphTags: IND;PRS;FIN;SG;V;3
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: bib, Lemma: bib, MorphTags: N;SG
#  Surface: pockets, Lemma: pocket, MorphTags: PL;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: sky, Lemma: sky, MorphTags: N;SG
#  Surface: is, Lemma: be, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: limit, Lemma: limit, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: He, Lemma: he, MorphTags: PRO;SG;NOM;MASC;3
#  Surface: successfully, Lemma: successfully, MorphTags: ADV
#  Surface: defended, Lemma: defend, MorphTags: V;PST;FIN;IND
#  Surface: his, Lemma: his, MorphTags: PRO;SG;MASC;3
#  Surface: dissertation, Lemma: dissertation, MorphTags: N;SG
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: 1891, Lemma: @card@, MorphTags: NUM
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: How, Lemma: How, MorphTags: CONJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: Hypnotize, Lemma: hypnotize, MorphTags: NFIN;V
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: Chicken, Lemma: Chicken, MorphTags: SG;N,
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: do, Lemma: do, MorphTags: PRS;V;FIN;IND
#  Surface: wear, Lemma: wear, MorphTags: NFIN;V
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: lot, Lemma: lot, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: black, Lemma: black, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Has, Lemma: have, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: internet, Lemma: Internet, MorphTags: SG;N
#  Surface: helped, Lemma: help, MorphTags: PST;V.PTCP;V
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: hurt, Lemma: hurt, MorphTags: PST;V.PTCP;V
#  Surface: magic, Lemma: magic, MorphTags: SG;N
#  Surface: ?, Lemma: ?, MorphTags: _,
#  Surface: There, Lemma: there, MorphTags: PRO
#  Surface: 's, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: misconception, Lemma: misconception, MorphTags: SG;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: industry, Lemma: industry, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Additionally, Lemma: additionally, MorphTags: ADV
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DEF;DET
#  Surface: analysis, Lemma: analysis, MorphTags: N;SG
#  Surface: address, Lemma: address, MorphTags: PRS;V;FIN;IND
#  Surface: the, Lemma: the, MorphTags: DEF;DET
#  Surface: perceived, Lemma: perceive, MorphTags: V;V.PTCP;PST
#  Surface: reasons, Lemma: reason, MorphTags: N;PL
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: reported, Lemma: report, MorphTags: V;V.PTCP;PST
#  Surface: discrimination, Lemma: discrimination, MorphTags: N;SG
#  Surface: experiences, Lemma: experience, MorphTags: N;PL
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Heald, Lemma: Heald, MorphTags: SG;PROPN
#  Surface: noted, Lemma: note, MorphTags: PST;FIN;IND;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: findings, Lemma: finding, MorphTags: PL;N
#  Surface: show, Lemma: show, MorphTags: PRS;FIN;IND;V
#  Surface: pollution, Lemma: pollution, MorphTags: SG;N
#  Surface: reduction, Lemma: reduction, MorphTags: SG;N
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: also, Lemma: also, MorphTags: ADV
#  Surface: important, Lemma: important, MorphTags: ADJ
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: As, Lemma: as, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: result, Lemma: result, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: wikiHow, Lemma: wikiHow, MorphTags: SG;PROPN
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: still, Lemma: still, MorphTags: ADV
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: size, Lemma: size, MorphTags: SG;N
#  Surface: that, Lemma: that, MorphTags: PRO
#  Surface: every, Lemma: every, MorphTags: DET
#  Surface: editor, Lemma: editor, MorphTags: SG;N
#  Surface: eventually, Lemma: eventually, MorphTags: ADV
#  Surface: gets, Lemma: get, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: know, Lemma: know, MorphTags: NFIN;V
#  Surface: other, Lemma: other, MorphTags: ADJ
#  Surface: editors, Lemma: editor, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Shake, Lemma: shake, MorphTags: NFIN;V
#  Surface: every, Lemma: every, MorphTags: DET
#  Surface: 15, Lemma: @card@, MorphTags: NUM
#  Surface: minutes, Lemma: minute, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Marie, Lemma: Marie, MorphTags: SG;PROPN
#  Surface: Galante, Lemma: Galante, MorphTags: SG;PROPN
#  Surface: :, Lemma: :, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: biggest, Lemma: big, MorphTags: RL;ADJ
#  Surface: island, Lemma: island, MorphTags: SG;N
#  Surface: out, Lemma: out, MorphTags: CONJ
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: mainland, Lemma: mainland, MorphTags: SG;N
#  Surface: Guadeloupe, Lemma: Guadeloupe, MorphTags: SG;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: First, Lemma: first, MorphTags: ADJ
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: all, Lemma: all, MorphTags: PRO
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: think, Lemma: think, MorphTags: PRS;FIN;IND;V
#  Surface: maybe, Lemma: maybe, MorphTags: ADV
#  Surface: they, Lemma: they, MorphTags: NOM;3;PRO;PL
#  Surface: have, Lemma: have, MorphTags: PRS;FIN;IND;V
#  Surface: bad, Lemma: bad, MorphTags: ADJ
#  Surface: teachers, Lemma: teacher, MorphTags: PL;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: which, Lemma: which, MorphTags: PRO
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: problem, Lemma: problem, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: eHow, Lemma: eHow, MorphTags: SG;PROPN
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: continues, Lemma: continue, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: be, Lemma: be, MorphTags: NFIN;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: largest, Lemma: large, MorphTags: RL;ADJ
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: how, Lemma: how, MorphTags: CONJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: website, Lemma: website, MorphTags: SG;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: world, Lemma: world, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: If, Lemma: if, MorphTags: CONJ
#  Surface: someone, Lemma: someone, MorphTags: SG;N
#  Surface: asks, Lemma: ask, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: you, Lemma: you, MorphTags: 2;PRO;ACC
#  Surface: why, Lemma: why, MorphTags: CONJ
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: pushed, Lemma: push, MorphTags: PST;FIN;IND;V
#  Surface: all, Lemma: all, MorphTags: PRO
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: buttons, Lemma: button, MorphTags: PL;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: can, Lemma: can, MorphTags: V;FIN
#  Surface: honestly, Lemma: honestly, MorphTags: ADV
#  Surface: say, Lemma: say, MorphTags: NFIN;V
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: ", Lemma: ", MorphTags: _
#  Surface: It, Lemma: it, MorphTags: NEUT;SG;NOM;3;PRO
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: just, Lemma: just, MorphTags: ADV
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: joke, Lemma: joke, MorphTags: SG;N
#  Surface: !, Lemma: !, MorphTags: _
#  Surface: ", Lemma: ", MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: stories, Lemma: storey, MorphTags: PL;N
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: first, Lemma: first, MorphTags: ADJ
#  Surface: period, Lemma: period, MorphTags: SG;N
#  Surface: (, Lemma: (, MorphTags: _
#  Surface: 1892, Lemma: @card@, MorphTags: NUM
#  Surface: –, Lemma: –, MorphTags: ADP
#  Surface: 94, Lemma: @card@, MorphTags: NUM
#  Surface: ), Lemma: ), MorphTags: _
#  Surface: suffered, Lemma: suffer, MorphTags: PST;FIN;IND;V
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: excessive, Lemma: excessive, MorphTags: ADJ
#  Surface: influence, Lemma: influence, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Heian, Lemma: Heian, MorphTags: SG;PROPN
#  Surface: poetry, Lemma: poetry, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: population, Lemma: population, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Łódź, Lemma: Łódź, MorphTags: SG;PROPN
#  Surface: soared, Lemma: soar, MorphTags: PST;FIN;IND;V
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: some, Lemma: some, MorphTags: DET
#  Surface: 4,000, Lemma: @card@, MorphTags: NUM
#  Surface: people, Lemma: people, MorphTags: PL;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: 1830s, Lemma: 1830s, MorphTags: PL;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: 40,000, Lemma: @card@, MorphTags: NUM
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: 1865, Lemma: @card@, MorphTags: NUM
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: over, Lemma: over, MorphTags: ADV
#  Surface: 300,000, Lemma: @card@, MorphTags: NUM
#  Surface: inhabitants, Lemma: inhabitant, MorphTags: PL;N
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: turn, Lemma: turn, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: century, Lemma: century, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: which, Lemma: which, MorphTags: PRO
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: an, Lemma: an, MorphTags: DET;INDF
#  Surface: unprecedented, Lemma: unprecedented, MorphTags: ADJ
#  Surface: growth, Lemma: growth, MorphTags: SG;N
#  Surface: on, Lemma: on, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: worldwide, Lemma: worldwide, MorphTags: ADJ
#  Surface: scale, Lemma: scale, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: As, Lemma: as, MorphTags: ADP
#  Surface: President, Lemma: President, MorphTags: PROPN;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: I, Lemma: I, MorphTags: PRO;SG;NOM;1
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: serve, Lemma: serve, MorphTags: V;NFIN
#  Surface: ALL, Lemma: all, MorphTags: PRO
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DEF;DET
#  Surface: people, Lemma: people, MorphTags: N;PL
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: America, Lemma: America, MorphTags: PROPN;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: guided, Lemma: guide, MorphTags: V;V.PTCP;PST
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DEF;DET
#  Surface: Constitution, Lemma: Constitution, MorphTags: PROPN;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: Coppergate, Lemma: Coppergate, MorphTags: SG;PROPN
#  Surface: excavations, Lemma: excavation, MorphTags: PL;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: 1970s, Lemma: 1970s, MorphTags: PL;N
#  Surface: revealed, Lemma: reveal, MorphTags: PST;FIN;IND;V
#  Surface: much, Lemma: much, MorphTags: ADV
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: Viking, Lemma: Viking, MorphTags: SG;PROPN
#  Surface: past, Lemma: past, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: request, Lemma: request, MorphTags: SG;N
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: advanced, Lemma: advance, MorphTags: PST;V.PTCP;V
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: Municipality, Lemma: municipality, MorphTags: SG;PROPN
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Livorno, Lemma: Livorno, MorphTags: SG;PROPN
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: 2010, Lemma: @card@, MorphTags: NUM
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: At, Lemma: at, MorphTags: ADP
#  Surface: some, Lemma: some, MorphTags: DET
#  Surface: point, Lemma: point, MorphTags: SG;N
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: another, Lemma: another, MorphTags: PRO
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: most, Lemma: most, MorphTags: RL;ADJ
#  Surface: people, Lemma: people, MorphTags: PL;N
#  Surface: realize, Lemma: realize, MorphTags: PRS;FIN;IND;V
#  Surface: that, Lemma: that, MorphTags: CONJ
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: world, Lemma: world, MorphTags: SG;N
#  Surface: does, Lemma: do, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: n't, Lemma: n't, MorphTags: NEG;PART
#  Surface: revolve, Lemma: revolve, MorphTags: NFIN;V
#  Surface: around, Lemma: around, MorphTags: ADP
#  Surface: them, Lemma: them, MorphTags: ACC;3;PRO;PL
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Asking, Lemma: ask, MorphTags: V.MSDR;V
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: help, Lemma: help, MorphTags: SG;N
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: work, Lemma: work, MorphTags: SG;N
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: school-related, Lemma: school, MorphTags: ADJ
#  Surface: problem, Lemma: problem, MorphTags: SG;N
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: almost, Lemma: almost, MorphTags: ADV
#  Surface: always, Lemma: always, MorphTags: ADV
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: good, Lemma: good, MorphTags: ADJ
#  Surface: bet, Lemma: bet, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: as, Lemma: as, MorphTags: CONJ
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: asking, Lemma: ask, MorphTags: V.MSDR;V
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: question, Lemma: question, MorphTags: SG;N
#  Surface: about, Lemma: about, MorphTags: ADP
#  Surface: something, Lemma: something, MorphTags: SG;N
#  Surface: striking, Lemma: strike, MorphTags: V.MSDR;V
#  Surface: about, Lemma: about, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: person, Lemma: person, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Eventually, Lemma: eventually, MorphTags: ADV
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: she, Lemma: she, MorphTags: 3;SG;NOM;FEM;PRO
#  Surface: got, Lemma: get, MorphTags: PST;FIN;IND;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: break, Lemma: break, MorphTags: SG;N
#  Surface: she, Lemma: she, MorphTags: 3;SG;NOM;FEM;PRO
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: so, Lemma: so, MorphTags: ADV
#  Surface: eager, Lemma: eager, MorphTags: ADJ
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: :, Lemma: :, MorphTags: _,
#  Surface: Zenghelis, Lemma: Zenghelis, MorphTags: SG;PROPN
#  Surface: described, Lemma: describe, MorphTags: PST;FIN;IND;V
#  Surface: her, Lemma: her, MorphTags: 3;SG;ACC;FEM;PRO
#  Surface: as, Lemma: as, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: most, Lemma: most, MorphTags: ADV
#  Surface: outstanding, Lemma: outstanding, MorphTags: ADJ
#  Surface: pupil, Lemma: pupil, MorphTags: SG;N
#  Surface: he, Lemma: he, MorphTags: SG;NOM;MASC;3;PRO
#  Surface: ever, Lemma: ever, MorphTags: ADV
#  Surface: taught, Lemma: teach, MorphTags: PST;FIN;IND;V
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DEF;DET
#  Surface: majority, Lemma: majority, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: outfits, Lemma: outfit, MorphTags: N;PL
#  Surface: involved, Lemma: involve, MorphTags: V;PST;FIN;IND
#  Surface: at, Lemma: at, MorphTags: CONJ
#  Surface: least, Lemma: least, MorphTags: RL;ADJ
#  Surface: some, Lemma: some, MorphTags: DET
#  Surface: elements, Lemma: element, MorphTags: N;PL
#  Surface: made, Lemma: make, MorphTags: V;V.PTCP;PST
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: scratch, Lemma: scratch, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: a, Lemma: a, MorphTags: INDF;DET
#  Surface: fantastic, Lemma: fantastic, MorphTags: ADJ
#  Surface: display, Lemma: display, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: craftsmanship, Lemma: craftsmanship, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Place, Lemma: place, MorphTags: NFIN;V
#  Surface: two, Lemma: two, MorphTags: NUM
#  Surface: parts, Lemma: part, MorphTags: PL;N
#  Surface: water, Lemma: water, MorphTags: SG;N
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: stock, Lemma: stock, MorphTags: SG;N
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: one, Lemma: one, MorphTags: NUM
#  Surface: part, Lemma: part, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: quinoa, Lemma: quinoa, MorphTags: SG;N
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: saucepan, Lemma: saucepan, MorphTags: SG;N
#  Surface: over, Lemma: over, MorphTags: ADP
#  Surface: medium-high, Lemma: medium-high, MorphTags: ADJ
#  Surface: heat, Lemma: heat, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: bring, Lemma: bring, MorphTags: NFIN;V
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: boil, Lemma: boil, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: --, Lemma: --, MorphTags: _
#  Surface: beautiful, Lemma: beautiful, MorphTags: ADJ
#  Surface: girls, Lemma: girl, MorphTags: PL;N
#  Surface: --, Lemma: --, MorphTags: _,
#  Surface: Do, Lemma: do, MorphTags: NFIN;V
# ...
#  Surface: -, Lemma: -, MorphTags: _
#  Surface: US-75, Lemma: US-75, MorphTags: SG;PROPN
#  Surface: South, Lemma: South, MorphTags: SG;PROPN
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: Bartlesville, Lemma: Bartlesville, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: OK, Lemma: OK, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: US-169, Lemma: US-169, MorphTags: SG;PROPN
#  Surface: South, Lemma: South, MorphTags: SG;PROPN
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: Coffeyville, Lemma: Coffeyville, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: KS, Lemma: KS, MorphTags: SG;PROPN
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Major, Lemma: major, MorphTags: SG;PROPN
#  Surface: general, Lemma: general, MorphTags: SG;PROPN
#  Surface: Fuad, Lemma: Fuad, MorphTags: SG;PROPN
#  Surface: Basya, Lemma: Basya, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: spokesman, Lemma: spokesman, MorphTags: SG;N
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: Indonesian, Lemma: Indonesian, MorphTags: ADJ
#  Surface: military, Lemma: military, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: said, Lemma: say, MorphTags: PST;FIN;IND;V
#  Surface: fisherman, Lemma: fisherman, MorphTags: SG;N
#  Surface: first, Lemma: first, MorphTags: ADV
#  Surface: noticed, Lemma: notice, MorphTags: PST;FIN;IND;V
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: people, Lemma: people, MorphTags: PL;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: warship, Lemma: warship, MorphTags: SG;N
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: deployed, Lemma: deploy, MorphTags: PST;V.PTCP;V
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: retrieve, Lemma: retrieve, MorphTags: NFIN;V
#  Surface: them, Lemma: them, MorphTags: ACC;3;PRO;PL
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: What, Lemma: What, MorphTags: PRO
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: okay, Lemma: okay, MorphTags: ADJ
#  Surface: ?, Lemma: ?, MorphTags: _,
#  Surface: In, Lemma: in, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: mid-town, Lemma: mid-town, MorphTags: SG;N
#  Surface: area, Lemma: area, MorphTags: SG;N
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: names, Lemma: name, MorphTags: PL;N
#  Surface: are, Lemma: be, MorphTags: PRS;V;FIN;IND
#  Surface: taken, Lemma: take, MorphTags: PST;V.PTCP;V
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: colleges, Lemma: college, MorphTags: PL;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: college, Lemma: college, MorphTags: SG;N
#  Surface: towns, Lemma: town, MorphTags: PL;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: For, Lemma: for, MorphTags: ADP
#  Surface: example, Lemma: example, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: husbands, Lemma: husband, MorphTags: PL;N
#  Surface: are, Lemma: be, MorphTags: FIN;V;IND;PRS
#  Surface: likely, Lemma: likely, MorphTags: ADJ
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: laugh, Lemma: laugh, MorphTags: NFIN;V
#  Surface: at, Lemma: at, MorphTags: ADP
#  Surface: jokes, Lemma: joke, MorphTags: PL;N
#  Surface: about, Lemma: about, MorphTags: ADP
#  Surface: wives, Lemma: wife, MorphTags: PL;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: vice, Lemma: vice, MorphTags: ADJ
#  Surface: versa, Lemma: versa, MorphTags: ADV
#  Surface: ;, Lemma: ;, MorphTags: _,
#  Surface: After, Lemma: after, MorphTags: ADP
#  Surface: 5, Lemma: 5, MorphTags: NUM
#  Surface: minutes, Lemma: minute, MorphTags: PL;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: quinoa, Lemma: quinoa, MorphTags: SG;N
#  Surface: should, Lemma: should, MorphTags: V;FIN
#  Surface: be, Lemma: be, MorphTags: NFIN;V
#  Surface: fully, Lemma: fully, MorphTags: ADV
#  Surface: cooked, Lemma: cook, MorphTags: PST;V.PTCP;V
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Passing, Lemma: pass, MorphTags: V;V.MSDR
#  Surface: a, Lemma: a, MorphTags: INDF;DET
#  Surface: Living, Lemma: live, MorphTags: V;V.MSDR
#  Surface: Wage, Lemma: Wage, MorphTags: N;SG
#  Surface: program, Lemma: program, MorphTags: N;SG
#  Surface: lifting, Lemma: lift, MorphTags: V;V.MSDR
#  Surface: people, Lemma: people, MorphTags: N;PL
#  Surface: out, Lemma: out, MorphTags: ADP
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: poverty, Lemma: poverty, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: By, Lemma: by, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: time, Lemma: time, MorphTags: SG;N
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: get, Lemma: get, MorphTags: PRS;FIN;IND;V
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: be, Lemma: be, MorphTags: NFIN;V
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: writer, Lemma: writer, MorphTags: SG;N
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: Onion, Lemma: onion, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: though, Lemma: though, MorphTags: ADV
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: odds, Lemma: odd, MorphTags: PL;N
#  Surface: are, Lemma: be, MorphTags: PRS;FIN;IND;V
#  Surface: you, Lemma: you, MorphTags: 2;PRO;NOM
#  Surface: are, Lemma: be, MorphTags: PRS;V;FIN;IND
#  Surface: going, Lemma: go, MorphTags: V.PTCP;PRS;V
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: succeed, Lemma: succeed, MorphTags: NFIN;V
#  Surface: because, Lemma: because, MorphTags: CONJ
#  Surface: we, Lemma: we, MorphTags: NOM;1;PRO;PL
#  Surface: make, Lemma: make, MorphTags: PRS;FIN;IND;V
#  Surface: it, Lemma: it, MorphTags: NEUT;SG;ACC;3;PRO
#  Surface: pretty, Lemma: pretty, MorphTags: ADV
#  Surface: challenging, Lemma: challenging, MorphTags: ADJ
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: As, Lemma: as, MorphTags: CONJ
#  Surface: tropical, Lemma: tropical, MorphTags: ADJ
#  Surface: cyclones, Lemma: cyclone, MorphTags: PL;N
#  Surface: make, Lemma: make, MorphTags: FIN;IND;PRS;V
#  Surface: landfall, Lemma: landfall, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: this, Lemma: this, MorphTags: DET;SG
#  Surface: energy, Lemma: energy, MorphTags: N;SG
#  Surface: source, Lemma: source, MorphTags: N;SG
#  Surface: is, Lemma: be, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: cut-off, Lemma: cut-off, MorphTags: V.PTCP;V;PST
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: they, Lemma: they, MorphTags: NOM;PRO;PL;3
#  Surface: rapidly, Lemma: rapidly, MorphTags: ADV
#  Surface: lose, Lemma: lose, MorphTags: FIN;IND;PRS;V
#  Surface: strength, Lemma: strength, MorphTags: N;SG
#  Surface: as, Lemma: as, MorphTags: CONJ
#  Surface: they, Lemma: they, MorphTags: NOM;PRO;PL;3
#  Surface: move, Lemma: move, MorphTags: FIN;IND;PRS;V
#  Surface: over, Lemma: over, MorphTags: ADP
#  Surface: land, Lemma: land, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Tropical, Lemma: tropical, MorphTags: ADJ
#  Surface: cyclones, Lemma: cyclone, MorphTags: PL;N
#  Surface: are, Lemma: be, MorphTags: FIN;V;IND;PRS
#  Surface: sustained, Lemma: sustain, MorphTags: V.PTCP;V;PST
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: form, Lemma: form, MorphTags: N;SG
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: energy, Lemma: energy, MorphTags: N;SG
#  Surface: called, Lemma: call, MorphTags: V.PTCP;V;PST
#  Surface: latent, Lemma: latent, MorphTags: ADJ
#  Surface: heat, Lemma: heat, MorphTags: N;SG
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: which, Lemma: which, MorphTags: PRO
#  Surface: is, Lemma: be, MorphTags: V;IND;PRS;FIN;SG;3
#  Surface: released, Lemma: release, MorphTags: V.PTCP;V;PST
#  Surface: by, Lemma: by, MorphTags: ADP
#  Surface: moisture, Lemma: moisture, MorphTags: N;SG
#  Surface: evaporated, Lemma: evaporate, MorphTags: V.PTCP;V;PST
#  Surface: from, Lemma: from, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: ocean, Lemma: ocean, MorphTags: N;SG
#  Surface: that, Lemma: that, MorphTags: PRO
#  Surface: condenses, Lemma: condense, MorphTags: IND;PRS;FIN;SG;V;3
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: form, Lemma: form, MorphTags: NFIN;V
#  Surface: rain, Lemma: rain, MorphTags: N;SG
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: This, Lemma: this, MorphTags: PRO;SG
#  Surface: was, Lemma: be, MorphTags: PST;SG;V;IND;3;FIN
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: my, Lemma: my, MorphTags: SG;1;PRO
#  Surface: third, Lemma: third, MorphTags: ADJ
#  Surface: year, Lemma: year, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: Biology, Lemma: biology, MorphTags: SG;N
#  Surface: study, Lemma: study, MorphTags: SG;N
#  Surface: I, Lemma: I, MorphTags: SG;NOM;1;PRO
#  Surface: think, Lemma: think, MorphTags: PRS;FIN;IND;V
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: IE6, Lemma: IE6, MorphTags: SG;PROPN
#  Surface: shipped, Lemma: ship, MorphTags: PST;FIN;IND;V
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: Windows, Lemma: window, MorphTags: SG;PROPN
#  Surface: XP, Lemma: XP, MorphTags: SG;PROPN
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: nearly, Lemma: nearly, MorphTags: ADV
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: decade, Lemma: decade, MorphTags: SG;N
#  Surface: ago, Lemma: ago, MorphTags: ADV
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: You, Lemma: you, MorphTags: NOM;2;PRO
#  Surface: will, Lemma: will, MorphTags: V;FIN
#  Surface: also, Lemma: also, MorphTags: ADV
#  Surface: often, Lemma: often, MorphTags: ADV
#  Surface: see, Lemma: see, MorphTags: V;NFIN
#  Surface: Thais, Lemma: Thai, MorphTags: PROPN;PL
#  Surface: doing, Lemma: do, MorphTags: V;V.MSDR
#  Surface: a, Lemma: a, MorphTags: INDF;DET
#  Surface: wai, Lemma: wai, MorphTags: N;SG
#  Surface: as, Lemma: as, MorphTags: CONJ
#  Surface: they, Lemma: they, MorphTags: PRO;NOM;3;PL
#  Surface: walk, Lemma: walk, MorphTags: PRS;V;FIN;IND
#  Surface: past, Lemma: past, MorphTags: ADV
#  Surface: temples, Lemma: temple, MorphTags: N;PL
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: spirit, Lemma: spirit, MorphTags: N;SG
#  Surface: houses, Lemma: house, MorphTags: N;PL
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Clothing, Lemma: clothing, MorphTags: SG;N
#  Surface: supply, Lemma: supply, MorphTags: SG;N
#  Surface: closet, Lemma: closet, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Historically, Lemma: historically, MorphTags: ADV
#  Surface: important, Lemma: important, MorphTags: ADJ
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: economically, Lemma: economically, MorphTags: ADV
#  Surface: crucial, Lemma: crucial, MorphTags: ADJ
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: these, Lemma: these, MorphTags: DET;PL
#  Surface: islands, Lemma: island, MorphTags: PL;N
#  Surface: today, Lemma: today, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: Port, Lemma: Port, MorphTags: SG;PROPN
#  Surface: Hutt, Lemma: Hutt, MorphTags: SG;PROPN
#  Surface: is, Lemma: be, MorphTags: PRS;SG;V;IND;3;FIN
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: ideal, Lemma: ideal, MorphTags: ADJ
#  Surface: location, Lemma: location, MorphTags: SG;N
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: short, Lemma: short, MorphTags: ADJ
#  Surface: browse, Lemma: browse, MorphTags: SG;N
#  Surface: around, Lemma: around, MorphTags: ADP
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: mecca, Lemma: mecca, MorphTags: SG;N
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: those, Lemma: those, MorphTags: DET;PL
#  Surface: photography, Lemma: photography, MorphTags: SG;N
#  Surface: buffs, Lemma: buff, MorphTags: PL;N
#  Surface: [, Lemma: [, MorphTags: _
#  Surface: 2, Lemma: 2, MorphTags: NUM
#  Surface: ], Lemma: ], MorphTags: _
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Build, Lemma: build, MorphTags: NFIN;V
#  Surface: in, Lemma: in, MorphTags: ADP
#  Surface: or, Lemma: or, MorphTags: CONJ
#  Surface: add, Lemma: add, MorphTags: NFIN;V
#  Surface: something, Lemma: something, MorphTags: SG;N
#  Surface: to, Lemma: to, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: elevator, Lemma: elevator, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: Cover, Lemma: cover, MorphTags: NFIN;V
#  Surface: containers, Lemma: container, MorphTags: PL;N
#  Surface: with, Lemma: with, MorphTags: ADP
#  Surface: clear, Lemma: clear, MorphTags: ADJ
#  Surface: plastic, Lemma: plastic, MorphTags: ADJ
#  Surface: kitchen, Lemma: kitchen, MorphTags: SG;N
#  Surface: wrap, Lemma: wrap, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: so, Lemma: so, MorphTags: ADV
#  Surface: they, Lemma: they, MorphTags: NOM;3;PRO;PL
#  Surface: stay, Lemma: stay, MorphTags: PRS;FIN;IND;V
#  Surface: moist, Lemma: moist, MorphTags: ADJ
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: The, Lemma: the, MorphTags: DET;DEF
#  Surface: straps, Lemma: strap, MorphTags: PL;N
#  Surface: on, Lemma: on, MorphTags: ADP
#  Surface: adults, Lemma: adult, MorphTags: PL;N
#  Surface: ’, Lemma: 's, MorphTags: PART
#  Surface: overalls, Lemma: overall, MorphTags: PL;N
#  Surface: often, Lemma: often, MorphTags: ADV
#  Surface: get, Lemma: get, MorphTags: FIN;V;IND;PRS
#  Surface: so, Lemma: so, MorphTags: ADV
#  Surface: twisted, Lemma: twisted, MorphTags: ADJ
#  Surface: during, Lemma: during, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: wash, Lemma: wash, MorphTags: N;SG
#  Surface: that, Lemma: that, MorphTags: CONJ
#  Surface: one, Lemma: one, MorphTags: PRO
#  Surface: wishes, Lemma: wish, MorphTags: IND;PRS;FIN;SG;V;3
#  Surface: she, Lemma: she, MorphTags: NOM;FEM;PRO;SG;3
#  Surface: had, Lemma: have, MorphTags: FIN;V;IND;PST
#  Surface: just, Lemma: just, MorphTags: ADV
#  Surface: used, Lemma: use, MorphTags: V.PTCP;V;PST
#  Surface: an, Lemma: an, MorphTags: DET;INDF
#  Surface: old, Lemma: old, MorphTags: ADJ
#  Surface: fashioned, Lemma: fashion, MorphTags: ADJ
#  Surface: washboard, Lemma: washboard, MorphTags: N;SG
#  Surface: instead, Lemma: instead, MorphTags: ADV
#  Surface: ., Lemma: ., MorphTags: _,
#  Surface: In, Lemma: in, MorphTags: ADP
#  Surface: fact, Lemma: fact, MorphTags: SG;N
#  Surface: ,, Lemma: ,, MorphTags: _
#  Surface: many, Lemma: many, MorphTags: ADJ
#  Surface: people, Lemma: people, MorphTags: PL;N
#  Surface: Wikinews, Lemma: Wikinews, MorphTags: SG;N
#  Surface: observed, Lemma: observe, MorphTags: PST;FIN;IND;V
#  Surface: took, Lemma: take, MorphTags: PST;FIN;IND;V
#  Surface: out, Lemma: out, MorphTags: ADP
#  Surface: their, Lemma: their, MorphTags: 3;PRO;PL
#  Surface: mobiles, Lemma: mobile, MorphTags: PL;N
#  Surface: as, Lemma: as, MorphTags: CONJ
#  Surface: they, Lemma: they, MorphTags: NOM;3;PRO;PL
#  Surface: left, Lemma: leave, MorphTags: PST;FIN;IND;V
#  Surface: for, Lemma: for, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: evening, Lemma: evening, MorphTags: SG;N
#  Surface: and, Lemma: and, MorphTags: CONJ
#  Surface: used, Lemma: use, MorphTags: PST;FIN;IND;V
#  Surface: their, Lemma: their, MorphTags: 3;PRO;PL
#  Surface: own, Lemma: own, MorphTags: ADJ
#  Surface: phone, Lemma: phone, MorphTags: SG;N
#  Surface: cameras, Lemma: camera, MorphTags: PL;N
#  Surface: to, Lemma: to, MorphTags: PART
#  Surface: make, Lemma: make, MorphTags: NFIN;V
#  Surface: one, Lemma: one, MorphTags: NUM
#  Surface: further, Lemma: further, MorphTags: CMPR;ADJ
#  Surface: record, Lemma: record, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: the, Lemma: the, MorphTags: DET;DEF
#  Surface: moment, Lemma: moment, MorphTags: SG;N
#  Surface: -, Lemma: -, MorphTags: _
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: photo, Lemma: photo, MorphTags: SG;N
#  Surface: of, Lemma: of, MorphTags: ADP
#  Surface: a, Lemma: a, MorphTags: DET;INDF
#  Surface: photo, Lemma: photo, MorphTags: SG;N
#  Surface: ., Lemma: ., MorphTags: _,
#  ...]

# %%
data_sizes = []
for language_name, stats in dataset_stats.items():
    row = {'Language': language_name, 'Size': stats['Number of tokens']}
    data_sizes.append(row)
data_sizes_df = pd.DataFrame(data_sizes)
data_sizes_df = data_sizes_df.set_index('Language')
step = 8
for i in range(step, len(data_sizes_df), step):
    data_sizes_df[i-step:i].plot.bar(figsize=(20,5))

# %% [markdown]
# ## Unique Surface words vs Unique Lemmas
# - All values are normalized by dataset sizes

# %%
surface_lemma_stats_list = []
for language_name, stats in dataset_stats.items():
    row = {'Language': language_name, 
           '# unique surface words': stats['Number of unique words'] / stats['Number of tokens'],
           '# unique lemmas': stats['Number of unique lemmas'] / stats['Number of tokens']
          }
    surface_lemma_stats_list.append(row)
surface_lemma_stats_df = pd.DataFrame(surface_lemma_stats_list)
surface_lemma_stats_df = surface_lemma_stats_df.set_index('Language')
step = 10
for i in range(step, len(surface_lemma_stats_df), step):
    surface_lemma_stats_df[i-step:i].plot.bar(figsize=(20,5))

# %% [markdown]
# ## Unique morphological features vs Unique morphological tags
# - All values are normalized by dataset sizes

# %%
morph_stats_list = []
for language_name, stats in dataset_stats.items():
    row = {'Language': language_name,  
           '# unique morphological features': stats['Number of unique morphological features'] / stats['Number of tokens'],
           '# unique morphological tags': stats['Number of unique morphological tags'] / stats['Number of tokens']
          }
    morph_stats_list.append(row)
morph_stats_df = pd.DataFrame(morph_stats_list)
morph_stats_df = morph_stats_df.set_index('Language')
step = 10
for i in range(step, len(morph_stats_df), step):
    morph_stats_df[i-step:i].plot.bar(figsize=(20,5))

# %%
print(morph_stats_df)
# Out:
#               # unique morphological features  # unique morphological tags
# Language
# English-GUM                          0.000564                     0.002458
# Turkish-IMST                         0.001206                     0.040869
